# %%
import graphviz.backend as be
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
import dtreeviz

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
viz = dtreeviz.dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# C:\Users\Mr Sagar Kumar\AppData\Local\Temp\ipykernel_18908\34955455.py:1: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 viz = dtreeviz.dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                feature_names=iris.feature_names,
#       5                class_names=["setosa", "versicolor", "virginica"])
#       6 viz
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from dtreeviz import dtreeviz  # Ensure dtreeviz is installed
import numpy as np

# Load the Iris dataset
iris = load_iris()
X_train = np.array(X_train).reshape(-1, len(iris.feature_names))  # Ensures 2D shape

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# Train the Decision Tree model
clas = DecisionTreeClassifier(max_depth=3)
clas.fit(X_train, y_train)  # Ensure clas is trained!
print("Type of clas:", type(clas))  # Should be <class 'sklearn.tree.DecisionTreeClassifier'>
print("Type of X_train:", type(X_train))  # Should be numpy.ndarray or DataFrame
print("Shape of X_train:", X_train.shape)  # Should be (N, features)
print("Type of y_train:", type(y_train))  # Should be numpy.ndarray or list
print("Shape of y_train:", y_train.shape)  # Should be (N,)
print("Feature names:", iris.feature_names)  # Should be a list of feature names

# Visualize using dtreeviz
viz = dtreeviz(clas, 
               X_train, 
               y_train, 
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])


viz  # Should display the tree visualization
# Out:
# Type of clas: <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Type of X_train: <class 'numpy.ndarray'>
# Shape of X_train: (120, 4)
# Type of y_train: <class 'numpy.ndarray'>
# Shape of y_train: (120,)
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# C:\Users\Mr Sagar Kumar\AppData\Local\Temp\ipykernel_18908\3795343285.py:24: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 24
#      21 print("Feature names:", iris.feature_names)  # Should be a list of feature names
#      23 # Visualize using dtreeviz
# ---> 24 viz = dtreeviz(clas,
#      25                X_train,
#      26                y_train,
# ...

# %%
import graphviz.backend as be
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
     

clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Mr Sagar Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File c:\Users\Mr Sagar Kumar\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# ...

# %%
from dtreeviz import dtreeviz

viz = dtreeviz(clas, 
               X_train, 
               y_train, 
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])

viz  # This should now work!
# Out:
# C:\Users\Mr Sagar Kumar\AppData\Local\Temp\ipykernel_18908\2088381831.py:3: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 from dtreeviz import dtreeviz
# ----> 3 viz = dtreeviz(clas,
#       4                X_train,
#       5                y_train,
#       6                feature_names=iris.feature_names,
#       7                class_names=["setosa", "versicolor", "virginica"])
#       9 viz  # This should now work!
#
# ...
